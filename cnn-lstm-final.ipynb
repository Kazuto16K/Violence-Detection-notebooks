# %% [markdown]
# ## Setting Imports

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import Conv2D, Flatten, GlobalAveragePooling2D, TimeDistributed, LSTM, MaxPooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Sequence, to_categorical
# Out:
# 2025-05-24 10:13:15.617983: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748081595.847968      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748081595.916314      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Setting Constants and Paths

# %%
data_dir = '/kaggle/input/violence-nonviolence-real-life-situations/Real_Life_Violence_Dataset'
CLASS_LIST = ['Violence','NonViolence']
seed = 42
img_height, img_width = 100, 100
batch_size = 8
SEQUENCE_LENGTH = 16

# %% [markdown]
# ## Data Preprocessing and Dataset Generation

# %% [markdown]
# ## Creating Dataset first

# %%
def extract_frames(video_path):

    frames = []
    video_reader = cv2.VideoCapture(video_path)
    total_frames = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_interval = max(total_frames//SEQUENCE_LENGTH,1)

    for i in range(SEQUENCE_LENGTH):

        video_reader.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)

        ret,frame = video_reader.read()
        if not ret:
            break

        resized_frame = cv2.resize(frame,(img_height,img_width))

        normalized_frame = resized_frame / 255.0

        frames.append(normalized_frame)

    video_reader.release()

    return frames

def create_dataset(max_vid_per_class = 750):

    features = []
    labels = []
    video_files_paths = []


    for class_index,class_name in enumerate(CLASS_LIST):

        print(f"Extracting Data of Class:{class_name}")

        files_list = os.listdir(os.path.join(data_dir,class_name))

        count = 0
        for filename in files_list:
            if count >= max_vid_per_class:
                break

            video_path = os.path.join(data_dir,class_name,filename)
            frames = extract_frames(video_path)

            if len(frames) == SEQUENCE_LENGTH:

                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_path)
                count += 1

            #print(f"Extraction of {filename} into frames. Completed {count}/{max_vid_per_class}")

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels

# %%
features,labels = create_dataset()
# Out:
# Extracting Data of Class:Violence
# Extracting Data of Class:NonViolence
# [h264 @ 0xcff6c140] mb_type 104 in P slice too large at 98 31
# [h264 @ 0xcff6c140] error while decoding MB 98 31
# [h264 @ 0xcff6c140] mb_type 104 in P slice too large at 98 31
# [h264 @ 0xcff6c140] error while decoding MB 98 31
# [h264 @ 0xcff6c140] mb_type 104 in P slice too large at 98 31
# [h264 @ 0xcff6c140] error while decoding MB 98 31
# [h264 @ 0xcff6c140] mb_type 104 in P slice too large at 98 31
# [h264 @ 0xcff6c140] error while decoding MB 98 31

# %%
from sklearn.model_selection import train_test_split

# %%
features_med,features_test,labels_med,labels_test = train_test_split(features,labels,
                                                                        test_size=0.1,
                                                                        random_state=seed)

# %%
features_train,features_val,labels_train,labels_val = train_test_split(features_med,labels_med,
                                                                        test_size=0.2,
                                                                        random_state=seed)

# %%
from tensorflow.keras.utils import to_categorical

# %%
ohc_labels_train = to_categorical(labels_train)
ohc_labels_val = to_categorical(labels_val)
ohc_labels_test = to_categorical(labels_test)

# %% [markdown]
# ## Creating the CNN+LSTM Model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
model = Sequential()

model.add(TimeDistributed(Conv2D(16, (3,3), padding='same', activation='relu'),
                         input_shape = (SEQUENCE_LENGTH, img_height, img_width, 3)))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(32, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(64, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(64, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(128, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Flatten()))

model.add(LSTM(128, activation='tanh', return_sequences=True))
model.add(LSTM(64,activation='tanh', return_sequences=False))

model.add(Dense(512, activation = 'relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(64, activation = 'relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(2, activation = 'softmax'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1748082417.509097      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1748082417.509732      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed (TimeDistributed)   │ (None, 16, 100, 100, 16)    │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_1 (TimeDistributed) │ (None, 16, 100, 100, 16)    │              64 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_2 (TimeDistributed) │ (None, 16, 50, 50, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_3 (TimeDistributed) │ (None, 16, 50, 50, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_4 (TimeDistributed) │ (None, 16, 50, 50, 32)      │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ (None, 16, 50, 50, 32)      │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_6 (TimeDistributed) │ (None, 16, 25, 25, 32)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_7 (TimeDistributed) │ (None, 16, 25, 25, 32)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_8 (TimeDistributed) │ (None, 16, 25, 25, 64)      │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_9 (TimeDistributed) │ (None, 16, 25, 25, 64)      │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_10                  │ (None, 16, 12, 12, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_11                  │ (None, 16, 12, 12, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_12                  │ (None, 16, 12, 12, 64)      │          36,928 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_13                  │ (None, 16, 12, 12, 64)      │             256 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_14                  │ (None, 16, 6, 6, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_15                  │ (None, 16, 6, 6, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_16                  │ (None, 16, 6, 6, 128)       │          73,856 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_17                  │ (None, 16, 6, 6, 128)       │             512 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_18                  │ (None, 16, 3, 3, 128)       │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_19                  │ (None, 16, 3, 3, 128)       │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_20                  │ (None, 16, 1152)            │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 16, 128)             │         655,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │          33,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          32,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 909,410 (3.47 MB)
#  Trainable params: 907,650 (3.46 MB)
#  Non-trainable params: 1,760 (6.88 KB)

# %% [markdown]
# ### Plotting the model

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='CNN+LSTM_model.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Setting the Callbacks

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', 
                                        patience = 10, 
                                        mode='min', 
                                        restore_best_weights=True)

checkpoint_callback = ModelCheckpoint(
    filepath = 'cnn_lstm.keras',
    save_weights_only = False,
    monitor='val_accuracy',
    mode = 'max',
    save_best_only = True
)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',  
                              factor=0.5,          
                              patience=8,          
                              min_lr=0.00001,         
                              verbose=1)

# %% [markdown]
# ## Training the Model

# %%
history = model.fit(x = features_train,
                    y = ohc_labels_train,
                    batch_size = batch_size,
                   epochs = 50,
                   validation_data = (features_val,ohc_labels_val),
                    shuffle=True,
                   callbacks=[early_stopping_callback,checkpoint_callback,reduce_lr])
# Out:
# Epoch 1/50
# E0000 00:00:1748082470.068624      35 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1/time_distributed_3_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1748082473.111906    6099 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 75s 205ms/step - accuracy: 0.5120 - loss: 3.2741 - val_accuracy: 0.5593 - val_loss: 2.4937 - learning_rate: 0.0010
# Epoch 2/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.5372 - loss: 2.6437 - val_accuracy: 0.6667 - val_loss: 2.1612 - learning_rate: 0.0010
# Epoch 3/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.6161 - loss: 2.1664 - val_accuracy: 0.5963 - val_loss: 1.9321 - learning_rate: 0.0010
# Epoch 4/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 150ms/step - accuracy: 0.6168 - loss: 1.9661 - val_accuracy: 0.4481 - val_loss: 2.0177 - learning_rate: 0.0010
# Epoch 5/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.6874 - loss: 1.6511 - val_accuracy: 0.7000 - val_loss: 1.4943 - learning_rate: 0.0010
# Epoch 6/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.7327 - loss: 1.4219 - val_accuracy: 0.6556 - val_loss: 1.4589 - learning_rate: 0.0010
# Epoch 7/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.7807 - loss: 1.2133 - val_accuracy: 0.6889 - val_loss: 1.2620 - learning_rate: 0.0010
# Epoch 8/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.8000 - loss: 1.0389 - val_accuracy: 0.6630 - val_loss: 1.1214 - learning_rate: 0.0010
# Epoch 9/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.7582 - loss: 0.9469 - val_accuracy: 0.7444 - val_loss: 0.9270 - learning_rate: 0.0010
# Epoch 10/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.7952 - loss: 0.8269 - val_accuracy: 0.6296 - val_loss: 1.1545 - learning_rate: 0.0010
# Epoch 11/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.8336 - loss: 0.7077 - val_accuracy: 0.6963 - val_loss: 0.8886 - learning_rate: 0.0010
# Epoch 12/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.8176 - loss: 0.6661 - val_accuracy: 0.6370 - val_loss: 1.0377 - learning_rate: 0.0010
# Epoch 13/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.8488 - loss: 0.5726 - val_accuracy: 0.6259 - val_loss: 0.8498 - learning_rate: 0.0010
# Epoch 14/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.8442 - loss: 0.5038 - val_accuracy: 0.6667 - val_loss: 0.7940 - learning_rate: 0.0010
# Epoch 15/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.8232 - loss: 0.5219 - val_accuracy: 0.8111 - val_loss: 0.5299 - learning_rate: 0.0010
# Epoch 16/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.8465 - loss: 0.4422 - val_accuracy: 0.7741 - val_loss: 0.6010 - learning_rate: 0.0010
# Epoch 17/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8725 - loss: 0.3860 - val_accuracy: 0.6667 - val_loss: 0.7925 - learning_rate: 0.0010
# Epoch 18/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.8685 - loss: 0.3892 - val_accuracy: 0.5667 - val_loss: 1.0225 - learning_rate: 0.0010
# Epoch 19/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.8529 - loss: 0.3971 - val_accuracy: 0.8296 - val_loss: 0.4649 - learning_rate: 0.0010
# Epoch 20/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 152ms/step - accuracy: 0.8617 - loss: 0.3743 - val_accuracy: 0.7000 - val_loss: 0.6713 - learning_rate: 0.0010
# Epoch 21/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.8931 - loss: 0.3282 - val_accuracy: 0.7630 - val_loss: 0.5488 - learning_rate: 0.0010
# Epoch 22/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.9018 - loss: 0.3145 - val_accuracy: 0.7556 - val_loss: 0.6364 - learning_rate: 0.0010
# Epoch 23/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.8928 - loss: 0.3133 - val_accuracy: 0.6815 - val_loss: 0.7706 - learning_rate: 0.0010
# Epoch 24/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 152ms/step - accuracy: 0.8996 - loss: 0.2927 - val_accuracy: 0.8222 - val_loss: 0.4813 - learning_rate: 0.0010
# Epoch 25/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9349 - loss: 0.2361 - val_accuracy: 0.8259 - val_loss: 0.4541 - learning_rate: 0.0010
# Epoch 26/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.8887 - loss: 0.3384 - val_accuracy: 0.7556 - val_loss: 0.5855 - learning_rate: 0.0010
# Epoch 27/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9198 - loss: 0.2615
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.9196 - loss: 0.2618 - val_accuracy: 0.7111 - val_loss: 0.6174 - learning_rate: 0.0010
# Epoch 28/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.9305 - loss: 0.2672 - val_accuracy: 0.8667 - val_loss: 0.4735 - learning_rate: 5.0000e-04
# Epoch 29/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9297 - loss: 0.2255 - val_accuracy: 0.8370 - val_loss: 0.4434 - learning_rate: 5.0000e-04
# Epoch 30/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.9357 - loss: 0.2291 - val_accuracy: 0.7852 - val_loss: 0.7400 - learning_rate: 5.0000e-04
# Epoch 31/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.9229 - loss: 0.2155 - val_accuracy: 0.8852 - val_loss: 0.3341 - learning_rate: 5.0000e-04
# Epoch 32/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.9185 - loss: 0.2431 - val_accuracy: 0.8444 - val_loss: 0.4097 - learning_rate: 5.0000e-04
# Epoch 33/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.9383 - loss: 0.2169 - val_accuracy: 0.8556 - val_loss: 0.5079 - learning_rate: 5.0000e-04
# Epoch 34/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9526 - loss: 0.1874 - val_accuracy: 0.8630 - val_loss: 0.4822 - learning_rate: 5.0000e-04
# Epoch 35/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9372 - loss: 0.2342 - val_accuracy: 0.8556 - val_loss: 0.3924 - learning_rate: 5.0000e-04
# Epoch 36/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.9497 - loss: 0.1729 - val_accuracy: 0.8667 - val_loss: 0.3621 - learning_rate: 5.0000e-04
# Epoch 37/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - accuracy: 0.9636 - loss: 0.1276 - val_accuracy: 0.8370 - val_loss: 0.4544 - learning_rate: 5.0000e-04
# Epoch 38/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9392 - loss: 0.2076 - val_accuracy: 0.8667 - val_loss: 0.4593 - learning_rate: 5.0000e-04
# Epoch 39/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9430 - loss: 0.2049
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9430 - loss: 0.2049 - val_accuracy: 0.8667 - val_loss: 0.4157 - learning_rate: 5.0000e-04
# Epoch 40/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9570 - loss: 0.1636 - val_accuracy: 0.8889 - val_loss: 0.3999 - learning_rate: 2.5000e-04
# Epoch 41/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.9626 - loss: 0.1751 - val_accuracy: 0.8593 - val_loss: 0.4715 - learning_rate: 2.5000e-04

# %% [markdown]
# ## Plotting the model performance

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    epochs = range(len(metric_value_1))

    plt.plot(epochs, metric_value_1, 'blue', label=metric_name_1)
    plt.plot(epochs, metric_value_2, 'orange', label=metric_name_2)
    plt.title(str(plot_name))
    plt.legend()

# %%
plot_metric(history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(history, 'accuracy', 'val_accuracy', 'Train Accuracy vs Validation Accuracy')

# %% [markdown]
# ## Testing and Model Evaluation

# %%
import time

# %%
print("labels_test shape:", labels_test.shape)
print("features_test shape:", features_test.shape)
# Out:
# labels_test shape: (150,)
# features_test shape: (150, 16, 100, 100, 3)

# %%
start_time = time.perf_counter()
loss, accuracy = model.evaluate(features_test, ohc_labels_test)
end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.6f} seconds")
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8149 - loss: 0.4246
# Elapsed time: 1.095439 seconds
# Test Loss: 0.36209842562675476
# Test Accuracy: 0.8600000143051147

# %%
labels_predict = model.predict(features_test)
labels_predict = np.argmax(labels_predict, axis=1)
labels_test_normal = np.argmax(ohc_labels_test, axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step

# %%
from sklearn.metrics import accuracy_score

AccScore = accuracy_score(labels_predict, labels_test_normal)
print('Accuracy Score is : ', AccScore)
# Out:
# Accuracy Score is :  0.86

# %% [markdown]
# ## Confusion Matrix Representation

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

ax = plt.subplot()
cm = confusion_matrix(labels_test_normal, labels_predict)
sns.heatmap(cm, annot=True, fmt='g', ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['Violence', 'NonViolence'])
ax.yaxis.set_ticklabels(['Violence', 'NonViolence'])

plt.savefig('/kaggle/working/confusion_matrix.png', format='png', dpi=300, bbox_inches='tight')

plt.show()
