# %% [markdown]
# ## Setting Imports

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import Conv2D, Flatten, GlobalAveragePooling2D, TimeDistributed, LSTM, MaxPooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Sequence, to_categorical
# Out:
# 2025-05-24 11:57:54.144672: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748087874.595482      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748087874.721714      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Setting Constants and Paths

# %%
data_dir = '/kaggle/input/violence-nonviolence-real-life-situations/Real_Life_Violence_Dataset'
CLASS_LIST = ['Violence','NonViolence']
seed = 42
img_height, img_width = 100, 100
batch_size = 8
SEQUENCE_LENGTH = 16

# %% [markdown]
# ## Data Preprocessing and Dataset Generation

# %% [markdown]
# ## Creating Dataset first

# %%
def extract_frames(video_path):

    frames = []
    video_reader = cv2.VideoCapture(video_path)
    total_frames = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_interval = max(total_frames//SEQUENCE_LENGTH,1)

    for i in range(SEQUENCE_LENGTH):

        video_reader.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)

        ret,frame = video_reader.read()
        if not ret:
            break

        resized_frame = cv2.resize(frame,(img_height,img_width))

        normalized_frame = resized_frame / 255.0

        frames.append(normalized_frame)

    video_reader.release()

    return frames

def create_dataset(max_vid_per_class = 750):

    features = []
    labels = []

    for class_index,class_name in enumerate(CLASS_LIST):

        print(f"Extracting Data of Class:{class_name}")

        files_list = os.listdir(os.path.join(data_dir,class_name))

        count = 0
        for filename in files_list:
            if count >= max_vid_per_class:
                break

            video_path = os.path.join(data_dir,class_name,filename)
            frames = extract_frames(video_path)

            if len(frames) == SEQUENCE_LENGTH:

                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_path)
                count += 1

            #print(f"Extraction of {filename} into frames. Completed {count}/{max_vid_per_class}")

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels

# %%
features,labels = create_dataset()
# Out:
# Extracting Data of Class:Violence
# Extracting Data of Class:NonViolence
# [h264 @ 0x91f197c0] mb_type 104 in P slice too large at 98 31
# [h264 @ 0x91f197c0] error while decoding MB 98 31
# [h264 @ 0x91f197c0] mb_type 104 in P slice too large at 98 31
# [h264 @ 0x91f197c0] error while decoding MB 98 31
# [h264 @ 0x91f197c0] mb_type 104 in P slice too large at 98 31
# [h264 @ 0x91f197c0] error while decoding MB 98 31
# [h264 @ 0x91f197c0] mb_type 104 in P slice too large at 98 31
# [h264 @ 0x91f197c0] error while decoding MB 98 31

# %%
from sklearn.model_selection import train_test_split

# %%
features_med,features_test,labels_med,labels_test = train_test_split(features,labels,
                                                                        test_size=0.1,
                                                                        random_state=seed)

# %%
features_train,features_val,labels_train,labels_val = train_test_split(features_med,labels_med,
                                                                        test_size=0.2,
                                                                        random_state=seed)

# %%
from tensorflow.keras.utils import to_categorical

# %%
ohc_labels_train = to_categorical(labels_train)
ohc_labels_val = to_categorical(labels_val)
ohc_labels_test = to_categorical(labels_test)

# %% [markdown]
# ## Creating the CNN+LSTM Model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
model = Sequential()

model.add(TimeDistributed(Conv2D(16, (3,3), padding='same', activation='relu'),
                         input_shape = (SEQUENCE_LENGTH, img_height, img_width, 3)))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(32, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(64, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(64, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Conv2D(128, (3,3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D(2,2)))
model.add(TimeDistributed(Dropout(0.4)))

model.add(TimeDistributed(Flatten()))

model.add(LSTM(128, activation='tanh', return_sequences=True))
model.add(LSTM(64,activation='tanh', return_sequences=False))

model.add(Dense(512, activation = 'relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(64, activation = 'relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(2, activation = 'softmax'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_21                  │ (None, 16, 100, 100, 16)    │             448 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_22                  │ (None, 16, 100, 100, 16)    │              64 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_23                  │ (None, 16, 50, 50, 16)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_24                  │ (None, 16, 50, 50, 16)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_25                  │ (None, 16, 50, 50, 32)      │           4,640 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_26                  │ (None, 16, 50, 50, 32)      │             128 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_27                  │ (None, 16, 25, 25, 32)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_28                  │ (None, 16, 25, 25, 32)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_29                  │ (None, 16, 25, 25, 64)      │          18,496 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_30                  │ (None, 16, 25, 25, 64)      │             256 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_31                  │ (None, 16, 12, 12, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_32                  │ (None, 16, 12, 12, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_33                  │ (None, 16, 12, 12, 64)      │          36,928 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_34                  │ (None, 16, 12, 12, 64)      │             256 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_35                  │ (None, 16, 6, 6, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_36                  │ (None, 16, 6, 6, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_37                  │ (None, 16, 6, 6, 128)       │          73,856 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_38                  │ (None, 16, 6, 6, 128)       │             512 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_39                  │ (None, 16, 3, 3, 128)       │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_40                  │ (None, 16, 3, 3, 128)       │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_41                  │ (None, 16, 1152)            │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 16, 128)             │         655,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 512)                 │          33,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │          32,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 909,410 (3.47 MB)
#  Trainable params: 907,650 (3.46 MB)
#  Non-trainable params: 1,760 (6.88 KB)

# %% [markdown]
# ### Plotting the model

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='CNN+LSTM_model.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Setting the Callbacks

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', 
                                        patience = 10, 
                                        mode='min', 
                                        restore_best_weights=True)

checkpoint_callback = ModelCheckpoint(
    filepath = 'cnn_lstm.keras',
    save_weights_only = False,
    monitor='val_accuracy',
    mode = 'max',
    save_best_only = True
)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',  
                              factor=0.5,          
                              patience=8,          
                              min_lr=0.00001,         
                              verbose=1)

# %% [markdown]
# ## Training the Model

# %%
history = model.fit(x = features_train,
                    y = ohc_labels_train,
                    batch_size = batch_size,
                   epochs = 50,
                   validation_data = (features_val,ohc_labels_val),
                    shuffle=True,
                   callbacks=[early_stopping_callback,checkpoint_callback,reduce_lr])
# Out:
# Epoch 1/50
# E0000 00:00:1748089756.674889      35 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1_1/time_distributed_24_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 78s 225ms/step - accuracy: 0.5098 - loss: 3.1315 - val_accuracy: 0.4481 - val_loss: 2.3953 - learning_rate: 0.0010
# Epoch 2/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.5371 - loss: 2.4719 - val_accuracy: 0.4481 - val_loss: 2.1243 - learning_rate: 0.0010
# Epoch 3/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.5687 - loss: 2.0806 - val_accuracy: 0.5259 - val_loss: 1.9325 - learning_rate: 0.0010
# Epoch 4/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.6350 - loss: 1.8276 - val_accuracy: 0.4481 - val_loss: 2.0171 - learning_rate: 0.0010
# Epoch 5/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.7224 - loss: 1.4357 - val_accuracy: 0.4519 - val_loss: 2.3036 - learning_rate: 0.0010
# Epoch 6/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - accuracy: 0.7039 - loss: 1.3314 - val_accuracy: 0.6667 - val_loss: 1.2620 - learning_rate: 0.0010
# Epoch 7/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.7634 - loss: 1.1113 - val_accuracy: 0.5630 - val_loss: 1.3105 - learning_rate: 0.0010
# Epoch 8/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.7886 - loss: 0.9465 - val_accuracy: 0.5222 - val_loss: 1.5819 - learning_rate: 0.0010
# Epoch 9/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.8098 - loss: 0.8192 - val_accuracy: 0.7148 - val_loss: 0.9982 - learning_rate: 0.0010
# Epoch 10/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.8305 - loss: 0.7106 - val_accuracy: 0.7296 - val_loss: 0.8359 - learning_rate: 0.0010
# Epoch 11/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.7708 - loss: 0.7087 - val_accuracy: 0.7926 - val_loss: 0.7338 - learning_rate: 0.0010
# Epoch 12/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8340 - loss: 0.5696 - val_accuracy: 0.7556 - val_loss: 0.7455 - learning_rate: 0.0010
# Epoch 13/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8209 - loss: 0.5440 - val_accuracy: 0.7148 - val_loss: 0.6925 - learning_rate: 0.0010
# Epoch 14/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8333 - loss: 0.5124 - val_accuracy: 0.7852 - val_loss: 0.6102 - learning_rate: 0.0010
# Epoch 15/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8028 - loss: 0.5391 - val_accuracy: 0.7852 - val_loss: 0.5742 - learning_rate: 0.0010
# Epoch 16/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8288 - loss: 0.4469 - val_accuracy: 0.7296 - val_loss: 0.6271 - learning_rate: 0.0010
# Epoch 17/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8347 - loss: 0.4330 - val_accuracy: 0.7704 - val_loss: 0.5970 - learning_rate: 0.0010
# Epoch 18/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8558 - loss: 0.3785 - val_accuracy: 0.7778 - val_loss: 0.5924 - learning_rate: 0.0010
# Epoch 19/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8760 - loss: 0.3434
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8760 - loss: 0.3433 - val_accuracy: 0.6778 - val_loss: 0.7514 - learning_rate: 0.0010
# Epoch 20/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8718 - loss: 0.3627 - val_accuracy: 0.7741 - val_loss: 0.5227 - learning_rate: 5.0000e-04
# Epoch 21/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - accuracy: 0.8827 - loss: 0.2959 - val_accuracy: 0.8481 - val_loss: 0.5185 - learning_rate: 5.0000e-04
# Epoch 22/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.8910 - loss: 0.3241 - val_accuracy: 0.8370 - val_loss: 0.5498 - learning_rate: 5.0000e-04
# Epoch 23/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - accuracy: 0.8907 - loss: 0.2744 - val_accuracy: 0.6222 - val_loss: 0.8379 - learning_rate: 5.0000e-04
# Epoch 24/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.9073 - loss: 0.2843 - val_accuracy: 0.8519 - val_loss: 0.4587 - learning_rate: 5.0000e-04
# Epoch 25/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9311 - loss: 0.2348 - val_accuracy: 0.8037 - val_loss: 0.4929 - learning_rate: 5.0000e-04
# Epoch 26/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9303 - loss: 0.2080 - val_accuracy: 0.8481 - val_loss: 0.3798 - learning_rate: 5.0000e-04
# Epoch 27/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9356 - loss: 0.1891 - val_accuracy: 0.8111 - val_loss: 0.6932 - learning_rate: 5.0000e-04
# Epoch 28/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - accuracy: 0.8913 - loss: 0.3082 - val_accuracy: 0.8852 - val_loss: 0.3475 - learning_rate: 5.0000e-04
# Epoch 29/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9357 - loss: 0.2214 - val_accuracy: 0.8296 - val_loss: 0.4729 - learning_rate: 5.0000e-04
# Epoch 30/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9244 - loss: 0.2536 - val_accuracy: 0.7222 - val_loss: 0.7417 - learning_rate: 5.0000e-04
# Epoch 31/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9290 - loss: 0.2374 - val_accuracy: 0.8481 - val_loss: 0.4311 - learning_rate: 5.0000e-04
# Epoch 32/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9141 - loss: 0.2614 - val_accuracy: 0.8333 - val_loss: 0.5039 - learning_rate: 5.0000e-04
# Epoch 33/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9386 - loss: 0.2160 - val_accuracy: 0.7630 - val_loss: 0.7651 - learning_rate: 5.0000e-04
# Epoch 34/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - accuracy: 0.9259 - loss: 0.2564 - val_accuracy: 0.8111 - val_loss: 0.5585 - learning_rate: 5.0000e-04
# Epoch 35/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - accuracy: 0.9330 - loss: 0.2275 - val_accuracy: 0.7556 - val_loss: 0.7884 - learning_rate: 5.0000e-04
# Epoch 36/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9357 - loss: 0.2262
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.9357 - loss: 0.2261 - val_accuracy: 0.8556 - val_loss: 0.3840 - learning_rate: 5.0000e-04
# Epoch 37/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9255 - loss: 0.2398 - val_accuracy: 0.8370 - val_loss: 0.4503 - learning_rate: 2.5000e-04
# Epoch 38/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9780 - loss: 0.1066 - val_accuracy: 0.8778 - val_loss: 0.4101 - learning_rate: 2.5000e-04

# %% [markdown]
# ## Plotting the model performance

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    epochs = range(len(metric_value_1))

    plt.plot(epochs, metric_value_1, 'blue', label=metric_name_1)
    plt.plot(epochs, metric_value_2, 'orange', label=metric_name_2)
    plt.title(str(plot_name))
    plt.legend()

# %%
plot_metric(history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(history, 'accuracy', 'val_accuracy', 'Train Accuracy vs Validation Accuracy')

# %% [markdown]
# ## Testing and Model Evaluation

# %%
import time

# %%
print("labels_test shape:", labels_test.shape)
print("features_test shape:", features_test.shape)
# Out:
# labels_test shape: (150,)
# features_test shape: (150, 16, 100, 100, 3)

# %%
start_time = time.perf_counter()
loss, accuracy = model.evaluate(features_test, ohc_labels_test)
end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.6f} seconds")
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8471 - loss: 0.4483
# Elapsed time: 0.810282 seconds
# Test Loss: 0.3621309995651245
# Test Accuracy: 0.8733333349227905

# %%
labels_predict = model.predict(features_test)
labels_predict = np.argmax(labels_predict, axis=1)
labels_test_normal = np.argmax(ohc_labels_test, axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step

# %%
from sklearn.metrics import accuracy_score

AccScore = accuracy_score(labels_predict, labels_test_normal)
print('Accuracy Score is : ', AccScore)
# Out:
# Accuracy Score is :  0.8733333333333333

# %% [markdown]
# ## Confusion Matrix Representation

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

ax = plt.subplot()
cm = confusion_matrix(labels_test_normal, labels_predict)
sns.heatmap(cm, annot=True, fmt='g', ax=ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['Violence', 'NonViolence'])
ax.yaxis.set_ticklabels(['Violence', 'NonViolence'])

plt.savefig('/kaggle/working/confusion_matrix.png', format='png', dpi=300, bbox_inches='tight')

plt.show()
